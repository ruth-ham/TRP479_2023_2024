# %% [markdown]
# # Dealing with errors
#
# ---
#
# ##General information
# **Sources**
#
# This lesson is inspired by the Geo-python module at the University of Helsinki which in turn acknowledges the Programming in Python lessons from the Software Carpentry organization. This version was adapted for Colab and a UK context by Ruth Hamilton.
#
# **About this document**
#
# This is a Google Colab Notebook. This particular notebook is designed to introduce you to a few of the basic concepts of programming in Python. Like other common notebook formats (e.g. Jupyter), the contents of this document are divided into cells, which can contain:
#
# Markdown-formatted text,
# Python code, or
# raw text
# You can execute a snippet of code in a cell by pressing Shift-Enter or by pressing the Run Cell button that appears when your cursor is on the cell .
#
# ---
#
# ## Interpreting error messages
#
# So far in the course we have encountered a number of different types of error messages in Python, but have not really discussed how to understand what the computer is trying to tell you when you get an error message.
# We'll do that below.
# For most Python errors you will see and exception raised when the error is encountered, providing some insight into what went wrong and where to look to fix it.

# %% [markdown]
# ### Reading error messages
#
# Let's imagine you've written the code below called to convert wind speeds from km/hr to m/s and you're dying to figure out how windy it is in [Halifax, Nova Scotia, Canada](https://www.theweathernetwork.com/ca/weather/nova-scotia/halifax) where they report wind speeds in km/hr.
#
# Unfortunately, when you run your script you observe the following:

# %%
wind_speed_km = 50
wind_speed_ms = wind_speed_km * 1000 / 3600

print(f'A wind speed of {wind_speed_km} km/hr is {wind_speed_ms} m/s.)

# %% [markdown]
# Let's break this example down and see what the error message says.
#
# Firstly, we can see that the error was on `line 4`.
#
# We also have the **type** of error, a `SyntaxError` in this case, as well as an indication about where it occurred on the line (indicated by the `^`). The location given by the line number is not always correct, but Python makes its best guess for where you should look to solve the problem. Clearly, this is handy information.
#
# The error in this example is one of the most common - we haven't 'closed' the quotation marks around our text.

# %%
#see if you can fix the error in the code below:
wind_speed_km = 50
wind_speed_ms = wind_speed_km * 1000 / 3600

print(f'A wind speed of {wind_speed_km} km/hr is {wind_speed_ms} m/s.)

# %%
#@title Click below to show the fixed code:
#see if you can fix the error in the code below:
wind_speed_km = 50
wind_speed_ms = wind_speed_km * 1000 / 3600

print(f'A wind speed of {wind_speed_km} km/hr is {wind_speed_ms} m/s.)

# %% [markdown]
# Let's consider another example, where you have fixed the `SyntaxError` above and now have made a function for calculating a wind speeds in m/s.
#
# When you run this script you encounter a new and bigger error message:

# %%
def convert_wind_speed(speed):
    return speed * 1000 / 3600

wind_speed_km = '30'
wind_speed_ms = convert_wind_speed(wind_speed_km)

print(f'A wind speed of {wind_speed_km} km/hr is {wind_speed_ms} m/s.')

# %% [markdown]
# In this case we see a `TypeError` that is part of a *traceback*, where the problem in the code arises from something other than on the line where the code was run.
#
# In this case, we have a `TypeError` where we try to divide a character string by a number, something Python cannot do. Hence, the `TypeError` indicating the data **types** are not compatible. That error, however, does not occur when the code is run until the point where the function is used. Thus, we see the traceback showing that not only does the error occur when the function is called, but also that the problem is in the function definition.
#
# The traceback above may look a bit scarier, but if you take your time and read through what is output, you will again find that the information is helpful in finding the problem in your code. After all, the purpose of the error message is to help the user find a problem :).

# %%
#try and fix the code below:
def convert_wind_speed(speed):
    return speed * 1000 / 3600

wind_speed_km = 30
wind_speed_ms = convert_wind_speed(wind_speed_km)

print(f'A wind speed of {wind_speed_km} km/hr is {wind_speed_ms} m/s.)

# %%
#@title Click below to show fixed code
#try and fix the code below:
def convert_wind_speed(speed):
    return speed * 1000 / 3600

wind_speed_km = 30
wind_speed_ms = convert_wind_speed(wind_speed_km)

print(f'A wind speed of {wind_speed_km} km/hr is {wind_speed_ms} m/s.')

# %% [markdown]
# ### Common errors and exceptions
#
# Now that we have some idea of how to read an error message, let's have a look at a few different types of common Python exceptions that are displayed for different program errors.
#
# #### IndexErrors
#
# An `IndexError` occurs when you attempt to reference a value with an index outside the range of values.
# We can easily produce an `IndexError` by trying to access the value at index 5 in the following list of cities: `cities = ['Paris', 'Berlin', 'London']`.

# %%
cities = ['Paris', 'Berlin', 'London']

# %%
cities[5]

# %% [markdown]
# Here we get the rather clear error message that the index used for the list `cities` is out of the range of index values for that list. Our list only has three elements - and because of zero indexing, we access the third element with `cities[2]` (or, to be safer, `cities[-1]`)

# %% [markdown]
# #### NameErrors
#
# A `NameError` occurs when you reference a variable that has not been defined. We can produce a `NameError` by trying `station_id = stations[1]`.

# %%
station_id = stations[1]

# %% [markdown]
# In this instance we receive a `NameError` because the list `stations` has not been defined, and we're thus not able to access a value in that list. You often get these when you open notebook you have been working on before and haven't executed all of the cells.

# %% [markdown]
# #### IndentationErrors
#
# An `IndentationError` is raised whenever a code block is expected to be indented and is either not, or is indented inconsistently. Let's consider two examples below.

# %%
for city in cities:
    city = city + ' is a city in Europe'
  print(city)

# %%
for city in cities:
city = city + ' is a city in Europe'
print(city)

# %% [markdown]
# In both of the examples above, an `IndentationError` is raised.
# * In the first case, the indentation level is inconsistent;
#  * ***either*** the `print(city)` statement is indented by 4 spaces - in which case it part of the `for` loop,
#   * ***or*** it is not indented at all - in which case it is executed after the `for` loop has completed.
#
# * In case two, indentation is expected in the statement following a `for` statement.
#
# ##Check your understanding
#
# Edit the two code cells below to fix the indentation errors:

# %%
for city in cities:
    city = city + ' is a city in Europe'
  print(city)

# %%
for city in cities:
city = city + ' is a city in Europe'
print(city)

# %% [markdown]
# #### TypeErrors
#
# A `TypeError` is raised whenever two incompatible data types are used together. For example, if we try to divide a character string by a number or add a number to a boolean variable, a `TypeError` will be raised.

# %%
cities[0] / 5

# %% [markdown]
# In this case, the `TypeError` is because it is not possible to divide a character string by a number.

# %% [markdown]
# #### Other kinds of errors
#
# There are certainly [other kinds of errors and exceptions in Python](https://docs.python.org/3/tutorial/errors.html), but this list comprises those you're most likely to encounter.
# As you can see, knowing the name of each error can be helpful in trying to figure out what has gone wrong, and knowing what these common error types mean will save you time trying to fix your programs.

# %% [markdown]
# ### More information on errors
#
# You can find a bit more information about reading error messages on the [Software Carpentry](https://swcarpentry.github.io/python-novice-inflammation/09-errors/index.html) and [Python Software Foundation](https://docs.python.org/3/tutorial/errors.html) webpages.
#
# Also, Python 3.10 was just released in October 2021. Among the changes in this release are [improvements in the error messages](https://docs.python.org/3.10/whatsnew/3.10.html#better-error-messages) that are generated for many of the cases above. We will not be using Python 3.10 in the course, but you can feel free to test it out if you like.
