# %% [markdown]
# Install OSMnx package using pip install
# Note, you will have to re-tart the runtime afterwards

# %%
pip install osmnx

# %% [markdown]
# Import the osmnx package

# %%
import osmnx as ox

# %%
#os.plot_graph(os.graph_from_place('Sheffield, UK'))
G = ox.project_graph(ox.graph_from_place('Sheffield, UK'))

# %%
G2 = ox.consolidate_intersections(G, tolerance=10, rebuild_graph=True, dead_ends=True)

# %%
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
city = ox.geocode_to_gdf(['Manchester, UK', 'Sheffield, UK','Leeds, UK'])
ax = ox.project_gdf(city).plot()
_ = ax.axis('off')
